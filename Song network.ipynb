# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import networkx as nx
import matplotlib.pyplot as plt
import re
import itertools
from tqdm import tqdm

# %% [markdown]
# # Creating song similarity networks from user's librairies

# %%
train =  pd.read_csv('data/train.csv')

# %%
songs = pd.read_csv('data/songs.csv')

# %% [markdown]
# First we sort the train table in order to group by user ID.

# %%
train.sort_values('msno', inplace=True)
train.reset_index(drop=True, inplace=True)

# %%
train
# Out:
#                                                  msno  \
# 0        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 1        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 2        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 3        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 4        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 5        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 6        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 7        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 8        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 9        ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 10       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 11       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 12       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 13       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 14       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 15       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 16       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 17       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 18       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 19       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 20       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 21       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 22       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 23       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 24       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 25       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 26       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 27       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 28       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# 29       ++5wYjoMgQHoRuD3GbbvmphZbBBwymzv5Q4l8sywtuU=
# ...                                               ...
# 7377388  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377389  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377390  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377391  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377392  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377393  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377394  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377395  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377396  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377397  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377398  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377399  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377400  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377401  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377402  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377403  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377404  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377405  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377406  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377407  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377408  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377409  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377410  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377411  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377412  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377413  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377414  zzqc2ja7z10FtSpagYVcAZXg/gPRq7wcDZuNFj+zJSU=
# 7377415  zzzRi5ek1YCKTGns8C77xwAutE05PAPmz8T/pIIQhzE=
# 7377416  zzzRi5ek1YCKTGns8C77xwAutE05PAPmz8T/pIIQhzE=
# 7377417  zzzRi5ek1YCKTGns8C77xwAutE05PAPmz8T/pIIQhzE=
#
#                                               song_id source_system_tab  \
# 0        DZanD98cLDbuPBiXONSwLFSw8BfI69ErQS23vYJ9UU4=        my library
# 1        E6Fm873UEDPv0LATidt2gKwBZZHww2Q04nxTg15N9iE=        my library
# 2        0TZ4BKn9YES2upK9ZgKgsAUtUClVKHnct79pnA/iPiQ=        my library
# 3        m2YSjnhR3nzx/2WccNYpGWywohyd8fT0xR+skQC9/JQ=        my library
# 4        cXpk2ZXiSgkwGo8iGbswBc0lzucL9AH+j/2khmnmOLI=        my library
# 5        l4oo7oWfRaS6ruFnWfHkAWEVjpcTr+J6T9Mf7l3/x+s=        my library
# 6        upH6pOAUd+iV/MkpzeELvqEFoTEIVhsV9eML8N7/gUM=        my library
# 7        0smF3rcYJymevsNGZbPZnTpUGLsgV/DvukNP9+3pZzI=        my library
# 8        a1iJZwnK13y6WORmBLHLoX/4k9WLwGGQ03cXVvdqhzM=        my library
# 9        9/M6UYUamqppFMo34jXxFApSujcu4eHl+yDaI3Gg6S4=        my library
# 10       CTwL9Gnx6QsaZ6+ygo/VHirN/XZKxlUJEB2VGQX8yjg=        my library
# 11       eXQkkbFryKxCMT0mIfXpWDYhOHn9G98sdlR11ym7ljU=        my library
# 12       AWNu8DBiFO1pTlpYyP0XXt4zcveklkV0qZ0vPQX1VDI=        my library
# 13       QRDeuc1HXUOiPIPrWfH1IQKaTskzIheM8QhGKrkUW3Q=        my library
# 14       FajQOvjIsz90IdeUkktmlG/SeO5iXj54erCpvQ1MdGU=        my library
# 15       yr9eZVcmBbqfcU2aO4ZNnZ7v8a8OdTS7cMuVUNQtMUg=          discover
# 7377403  /ICfsSWYBmWM2ga4bsn0NVK/GVGc+ZuDqW7sDndzUQ8=        my library
# 7377404  cwrBjdH3SkuUxlQOZipnCuhDmvTbsjsbuI88c3qdOXg=        my library
# 7377405  dIrGYq+Xuw4ztt7wagyf2RK0Wdb7p18xvZVHzI2+a1U=        my library
# 7377406  qIrAqKtDPBACcsAjZWh9OXYSfGYzx8Wwcz5szbX/n+E=        my library
# 7377407  bBIcBI4C53jjpVB43tlwrI3rSCjb40nGU855a1B54Jo=        my library
# 7377408  gu/pwE5lit9dFyzegC9fh//0Ed67xy2AqSKY6H7hAOw=        my library
# 7377409  c60LEIDQqbJs0ndivsocTLsSy2zdTg69KXPFmenhm1M=        my library
# 7377410  H7lei7suBiZl2nOz6qJahaRqEKRKYIn3ru2O8PDAGkk=        my library
# 7377411  4ZISq5iNKgBGGW2OvKBBzBsYXRohcJYFkqx3uVFCAuA=        my library
# 7377412  QmZ2VKtW9jXdffR1+3YDLkUWf3JmwDu2qHWu1FFwfbU=        my library
# 7377413  5Qh7YI03x2cbQFFv/e+faYhVpFAzjvnuE3YXkx2KgsQ=        my library
# 7377414  vldg6m5rQExUQNpVq0W/L/0VeDC6ktIFC/u2ezAudO4=        my library
# 7377415  wBTWuHbjdjxnG1lQcbqnK4FddV24rUhuyrYLd9c/hmk=        my library
# 7377416  rqNd52MxQ+okfR61j2c7u36DLODO4d2Zt/hMm3jxncM=        my library
# 7377417  PgRtmmESVNtWjoZHO5a1r21vIz9sVZmcJJpFCbRa1LI=        my library
#
#            source_screen_name          source_type  target
# 0         Local playlist more        local-library       1
# 1         Local playlist more        local-library       1
# 2         Local playlist more        local-library       1
# 3         Local playlist more        local-library       1
# 4         Local playlist more       local-playlist       0
# 5         Local playlist more       local-playlist       0
# 6         Local playlist more        local-library       1
# 7         Local playlist more       local-playlist       0
# 8         Local playlist more       local-playlist       0
# 9         Local playlist more       local-playlist       0
# 10        Local playlist more        local-library       0
# 11        Local playlist more       local-playlist       1
# 12        Local playlist more       local-playlist       1
# 13        Local playlist more       local-playlist       1
# 14                        NaN  top-hits-for-artist       0
# 15       Online playlist more      online-playlist       1
# 16        Local playlist more        local-library       0
# 17        Local playlist more        local-library       0
# 18        Local playlist more        local-library       1
# 19        Local playlist more       local-playlist       1
# 20        Local playlist more        local-library       1
# 21        Local playlist more        local-library       1
# 22                        NaN  top-hits-for-artist       0
# 23        Local playlist more       local-playlist       1
# 24        Local playlist more        local-library       0
# 25        Local playlist more        local-library       0
# 26       Online playlist more      online-playlist       0
# 27                        NaN  top-hits-for-artist       0
# 28                 My library       local-playlist       1
# 29        Local playlist more        local-library       0
# ...                       ...                  ...     ...
# 7377388   Local playlist more       local-playlist       1
# 7377389   Local playlist more       local-playlist       0
# 7377390   Local playlist more       local-playlist       0
# 7377391   Local playlist more       local-playlist       1
# 7377392   Local playlist more       local-playlist       0
# 7377393   Local playlist more       local-playlist       0
# 7377394   Local playlist more       local-playlist       1
# 7377395   Local playlist more       local-playlist       1
# 7377396   Local playlist more       local-playlist       0
# 7377397   Local playlist more       local-playlist       1
# 7377398   Local playlist more       local-playlist       0
# 7377399   Local playlist more       local-playlist       0
# 7377400   Local playlist more       local-playlist       1
# 7377401   Local playlist more       local-playlist       0
# 7377402   Local playlist more       local-playlist       1
# 7377403   Local playlist more       local-playlist       1
# 7377404   Local playlist more       local-playlist       0
# 7377405                Search      online-playlist       0
# 7377406   Local playlist more       local-playlist       1
# 7377407   Local playlist more       local-playlist       0
# 7377408   Local playlist more       local-playlist       0
# 7377409   Local playlist more       local-playlist       1
# 7377410   Local playlist more       local-playlist       0
# 7377411   Local playlist more       local-playlist       1
# 7377412   Local playlist more       local-playlist       1
# 7377413   Local playlist more       local-playlist       1
# 7377414   Local playlist more       local-playlist       1
# 7377415                Search                 song       1
# 7377416            Album more                album       1
# 7377417         Search Trends                 song       0
#
# [7377418 rows x 6 columns]

# %% [markdown]
# Then we create the adjacency matrix that contains all the songs in the dataset. We also keep track of whether the songs were found in the same library in a boolean adjacency matrix. We can then subtract the complete matrix with the boolean matrix to remove spurious song interactions and create a lighter graph.

# %%
unique_songs = train['song_id'].unique()
unique_song_id = dict(zip(unique_songs, range(len(unique_songs))))

# %%
from scipy.sparse import csr_matrix, dok_matrix

songs_adj_matrix = csr_matrix((len(unique_songs), len(unique_songs)), dtype=np.uint16)
songs_unique_adj = dok_matrix((len(unique_songs), len(unique_songs)), dtype=bool)

# %%
unique_users = train['msno'].unique()

for i, unique_user in tqdm(enumerate(unique_users[:1000])):
    # Retrieve unique user's "library" of songs listened to.
    start_index = train['msno'].searchsorted(unique_users[i])[0]
    if not i == (len(unique_users)-1):
        stop_index = train['msno'].searchsorted(unique_users[i+1])[0]
    else:
        stop_index = len(train)
    unique_user_library = train.iloc[start_index:stop_index]['song_id']
    
    # Add to the the global adjacency song matrix.
    dct = {}
    for edge in itertools.permutations(unique_user_library,2):
        dct[(unique_song_id[edge[0]], unique_song_id[edge[1]])] = 1
    
    unique_user_library_matrix = dok_matrix((len(unique_songs), len(unique_songs)), dtype=np.int16)
    songs_unique_adj.update(dct)
    unique_user_library_matrix.update(dct)
    
    songs_adj_matrix = unique_user_library_matrix + songs_adj_matrix
# Out:
# 0it [00:00, ?it/s]
# 1000it [1:27:53, 13.11s/it]

# %%
len(unique_users) * 10 / 60 / 60

# %%
songs_adj_matrix
# Out:
# <359966x359966 sparse matrix of type '<class 'numpy.int32'>'
# 	with 103595612 stored elements in Compressed Sparse Column format>

# %%
songs_adj_matrix = songs_adj_matrix - songs_unique_adj
song_adj_matrix

# %%
graph = nx.from_scipy_sparse_matrix(songs_adj_matrix)

# %%
subg = graph.subgraph([unique_song_id[song] for song in train[train['msno'] == unique_user]['song_id']])
